# %% [markdown]
# # SpamShield — Exploratory Data Analysis (EDA)
# ## SMS Spam Collection: Empirical Distributions & Discriminative Signal Extraction
#
# This notebook conducts in-depth exploratory data analysis on the **UCI SMS Spam Collection**.
# We investigate class imbalance, text length dynamics, syntactic markers (URLs, currency symbols, capitalization, punctuation bursts), and token frequency distributions.

# %%
import sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Setup project path
BASE_DIR = Path.cwd().parent
if str(BASE_DIR) not in sys.path:
    sys.path.insert(0, str(BASE_DIR))

from src.data_loader import load_raw_sms_dataset, clean_primary_dataset
from src.eda import run_full_eda
from src.preprocessor import extract_meta_features

# %% [markdown]
# ### 1. Ingestion & Preprocessing Inspection

# %%
raw_df = load_raw_sms_dataset()
clean_df, stats = clean_primary_dataset(raw_df, remove_duplicates=True)
print(f"Raw Shape: {stats['initial_shape']}")
print(f"Duplicates Dropped: {stats['duplicate_count']}")
print(f"Clean Shape: {stats['final_shape']}")
clean_df.head(10)

# %% [markdown]
# ### 2. Generate and Display Publication-Ready EDA Visualizations

# %%
eda_stats = run_full_eda(clean_df)
pd.Series(eda_stats)

# %% [markdown]
# ### 3. Display Class Distribution and Length Distributions

# %%
from IPython.display import Image, display
display(Image(filename=str(BASE_DIR / 'outputs' / 'eda' / '01_class_distribution.png')))
display(Image(filename=str(BASE_DIR / 'outputs' / 'eda' / '02_message_length_distribution.png')))
display(Image(filename=str(BASE_DIR / 'outputs' / 'eda' / '07_wordclouds_spam_vs_ham.png')))
display(Image(filename=str(BASE_DIR / 'outputs' / 'eda' / '08_feature_correlation_heatmap.png')))
